# %%
# !pip install --upgrade gspread
# !pip install --upgrade gspread-pandas
# !pip install --upgrade gspread-dataframe

import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.layers import Input, concatenate, Embedding, Reshape, Conv2D, MaxPooling2D
from keras.layers import Flatten, concatenate, Lambda, Dropout
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.regularizers import l2, l1_l2
from keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from google.colab import auth
auth.authenticate_user()
import gspread
import gspread_dataframe 
from oauth2client.client import GoogleCredentials

files = []
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-0.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-1.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-2.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-3.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-4.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-5.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-6.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-7.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-8.csv", header=None, skiprows=1)))
files.append(np.array(pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/10set (đủ mã)/AMD_Benign_ver2(tong hop)/file-9.csv", header=None, skiprows=1)))
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied, skipping upgrade: requests>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from gspread) (1.17.2)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from gspread) (0.4.2)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (4.2.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (51.0.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (4.6)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already up-to-date: gspread-pandas in /usr/local/lib/python3.6/dist-packages (2.2.3)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from gspread-pandas) (0.16.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib in /usr/local/lib/python3.6/dist-packages (from gspread-pandas) (0.4.2)
# Requirement already satisfied, skipping upgrade: decorator in /usr/local/lib/python3.6/dist-packages (from gspread-pandas) (4.4.2)
# Requirement already satisfied, skipping upgrade: google-auth in /usr/local/lib/python3.6/dist-packages (from gspread-pandas) (1.17.2)
# Requirement already satisfied, skipping upgrade: gspread>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from gspread-pandas) (3.6.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from gspread-pandas) (1.1.5)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib->gspread-pandas) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth->gspread-pandas) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth->gspread-pandas) (4.2.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth->gspread-pandas) (51.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth->gspread-pandas) (1.15.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth->gspread-pandas) (4.6)
# Requirement already satisfied, skipping upgrade: requests>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from gspread>=3.0.0->gspread-pandas) (2.23.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->gspread-pandas) (2018.9)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->gspread-pandas) (1.19.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->gspread-pandas) (2.8.1)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread-pandas) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth->gspread-pandas) (0.4.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-pandas) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-pandas) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-pandas) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-pandas) (1.24.3)
# Requirement already up-to-date: gspread-dataframe in /usr/local/lib/python3.6/dist-packages (3.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from gspread-dataframe) (1.15.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.24.0 in /usr/local/lib/python3.6/dist-packages (from gspread-dataframe) (1.1.5)
# Requirement already satisfied, skipping upgrade: gspread>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from gspread-dataframe) (3.6.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->gspread-dataframe) (1.19.4)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->gspread-dataframe) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->gspread-dataframe) (2.8.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from gspread>=3.0.0->gspread-dataframe) (0.4.2)
# Requirement already satisfied, skipping upgrade: requests>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from gspread>=3.0.0->gspread-dataframe) (2.23.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from gspread>=3.0.0->gspread-dataframe) (1.17.2)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (1.3.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (2020.12.5)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (4.2.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (51.0.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (4.6)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.4.8)

# %%
def tranform(data):
  deep_input_length = data.shape[1]
  size = int(math.ceil(deep_input_length**0.5))
  padding = size**2 - deep_input_length

  data = np.concatenate((data, np.zeros((data.shape[0], padding))), 1)
  data = data.reshape(data.shape[0], size, size, 1)
  return data

def WnDCNN(wide_input_shape, deep_input_shape):
  wide_input_shape = (wide_input_shape[1], )
  deep_input_shape = (deep_input_shape[1], deep_input_shape[2], deep_input_shape[3])
  #wide
  wide_input = Input(shape=wide_input_shape, name='wide_input')
  #deep
  deep_input = Input(shape=deep_input_shape, name='deep_input')
  conv1 = Conv2D(32, kernel_size=2, activation='relu', padding="same" ,input_shape=(128, 128, 1))(deep_input)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

  conv2 = Conv2D(32, kernel_size=2, activation='relu', padding="same")(pool1)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

  conv3 = Conv2D(64, kernel_size=2, activation='relu', padding="same")(pool2)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

  flatten_per = Flatten()(pool3)

  deep = Dense(1024, activation='relu')(flatten_per)
  deep = Dropout(0.3)(deep)
  deep = Dense(512, activation='relu')(deep)
  deep = Dropout(0.3)(deep)
  #wide & deep
  wide_deep_input = concatenate([wide_input, deep])
  wide_deep_out = Dense(228, activation='softmax', name='wide_deep')(wide_deep_input)
  wide_deep = Model(inputs=[wide_input, deep_input], outputs=wide_deep_out)
  wide_deep.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
  wide_deep.summary()
  return wide_deep

# %% [markdown]
# Bước 1: 4 máy train độc lập: val - file0, test - file1
# *   server (file2)
# *   client1 (file3)
# *   client2 (file 4)
# *   client3 (file 5)

# %%
x_val_wide = files[0][:, 16386:].astype('float')
x_val_deep = tranform(files[0][:, 3:16386]).astype('float')
y_val = to_categorical(files[0][:, 2].astype('int'), 228)

x_test_wide = files[1][:, 16386:].astype('float')
x_test_deep = tranform(files[1][:, 3:16386]).astype('float')
y_test = files[1][:, 2].astype('int')

wide_input_shape = x_val_wide.shape
deep_input_shape = x_val_deep.shape
#server
print('===============  Server  ================')
x_train_wide = files[2][:, 16386:].astype('float')
x_train_deep = tranform(files[2][:, 3:16386]).astype('float')
y_train = to_categorical(files[2][:, 2].astype('int'), 228)
server = WnDCNN(wide_input_shape, deep_input_shape)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_server.h5', monitor='val_loss', save_best_only=True)]
server.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Server ===============')
del x_train_wide, x_train_deep, y_train
#client1
print('===============  Client1  ================')
x_train_wide = files[3][:, 16386:].astype('float')
x_train_deep = tranform(files[3][:, 3:16386]).astype('float')
y_train = to_categorical(files[3][:, 2].astype('int'), 228)
client1 = WnDCNN(wide_input_shape, deep_input_shape)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_client1.h5', monitor='val_loss', save_best_only=True)]
client1.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Client1 ===============')
del x_train_wide, x_train_deep, y_train
#client2
print('===============  Client2  ================')
x_train_wide = files[4][:, 16386:].astype('float')
x_train_deep = tranform(files[4][:, 3:16386]).astype('float')
y_train = to_categorical(files[4][:, 2].astype('int'), 228)
client2 = WnDCNN(wide_input_shape, deep_input_shape)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_client2.h5', monitor='val_loss', save_best_only=True)]
client2.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Client2 ===============')
del x_train_wide, x_train_deep, y_train
#client3
print('===============  Client3  ================')
x_train_wide = files[5][:, 16386:].astype('float')
x_train_deep = tranform(files[5][:, 3:16386]).astype('float')
y_train = to_categorical(files[5][:, 2].astype('int'), 228)
client3 = WnDCNN(wide_input_shape, deep_input_shape)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_client3.h5', monitor='val_loss', save_best_only=True)]
client3.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Client3 ===============')
del x_train_wide, x_train_deep, y_train
# Out:
# ===============  Server  ================
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 160         deep_input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   4128        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   8256        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 16384)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         16778240    flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 1878)]       0
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2390)         0           wide_input[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# wide_deep (Dense)               (None, 228)          545148      concatenate[0][0]
# ==================================================================================================
# Total params: 17,860,732
# Trainable params: 17,860,732
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 41/41 [==============================] - 6s 42ms/step - loss: 32.5436 - accuracy: 0.2390 - val_loss: 1.3177 - val_accuracy: 0.7973
# Epoch 2/30
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1512 - accuracy: 0.7618 - val_loss: 0.8034 - val_accuracy: 0.8484
# Epoch 3/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6687 - accuracy: 0.8629 - val_loss: 0.5991 - val_accuracy: 0.8878
# Epoch 4/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4376 - accuracy: 0.9098 - val_loss: 0.5279 - val_accuracy: 0.8801
# Epoch 5/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2934 - accuracy: 0.9473 - val_loss: 0.4249 - val_accuracy: 0.9195
# Epoch 6/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1898 - accuracy: 0.9744 - val_loss: 0.3834 - val_accuracy: 0.9226
# Epoch 7/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1293 - accuracy: 0.9863 - val_loss: 0.3614 - val_accuracy: 0.9400
# Epoch 8/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1042 - accuracy: 0.9932 - val_loss: 0.3994 - val_accuracy: 0.9118
# Epoch 9/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0688 - accuracy: 0.9991 - val_loss: 0.3826 - val_accuracy: 0.9153
# ============== End Server ===============
# ===============  Client1  ================
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 160         deep_input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   4128        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   8256        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 16384)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         16778240    flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          524800      dropout_2[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 1878)]       0
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2390)         0           wide_input[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# wide_deep (Dense)               (None, 228)          545148      concatenate_1[0][0]
# ==================================================================================================
# Total params: 17,860,732
# Trainable params: 17,860,732
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 41/41 [==============================] - 2s 37ms/step - loss: 56.3948 - accuracy: 0.2021 - val_loss: 1.4464 - val_accuracy: 0.7861
# Epoch 2/30
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1862 - accuracy: 0.7732 - val_loss: 0.8580 - val_accuracy: 0.8476
# Epoch 3/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6767 - accuracy: 0.8789 - val_loss: 0.6209 - val_accuracy: 0.8936
# Epoch 4/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4333 - accuracy: 0.9201 - val_loss: 0.4942 - val_accuracy: 0.9188
# Epoch 5/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2766 - accuracy: 0.9529 - val_loss: 0.4088 - val_accuracy: 0.9242
# Epoch 6/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1888 - accuracy: 0.9705 - val_loss: 0.3800 - val_accuracy: 0.9226
# Epoch 7/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1287 - accuracy: 0.9837 - val_loss: 0.3437 - val_accuracy: 0.9311
# Epoch 8/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0811 - accuracy: 0.9974 - val_loss: 0.3941 - val_accuracy: 0.9126
# Epoch 9/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0491 - accuracy: 0.9986 - val_loss: 0.3500 - val_accuracy: 0.9253
# ============== End Client1 ===============
# ===============  Client2  ================
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 32) 160         deep_input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 32)   4128        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   8256        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 16384)        0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         16778240    flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          524800      dropout_4[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 1878)]       0
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2390)         0           wide_input[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# wide_deep (Dense)               (None, 228)          545148      concatenate_2[0][0]
# ==================================================================================================
# Total params: 17,860,732
# Trainable params: 17,860,732
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 41/41 [==============================] - 2s 38ms/step - loss: 41.2285 - accuracy: 0.2150 - val_loss: 1.4167 - val_accuracy: 0.7230
# Epoch 2/30
# 41/41 [==============================] - 1s 26ms/step - loss: 1.1892 - accuracy: 0.7473 - val_loss: 0.8929 - val_accuracy: 0.8553
# Epoch 3/30
# 41/41 [==============================] - 1s 25ms/step - loss: 0.6523 - accuracy: 0.8804 - val_loss: 0.6420 - val_accuracy: 0.8747
# Epoch 4/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4505 - accuracy: 0.9167 - val_loss: 0.5137 - val_accuracy: 0.9064
# Epoch 5/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2859 - accuracy: 0.9560 - val_loss: 0.4445 - val_accuracy: 0.9219
# Epoch 6/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1986 - accuracy: 0.9698 - val_loss: 0.4295 - val_accuracy: 0.9203
# Epoch 7/30
# 41/41 [==============================] - 1s 25ms/step - loss: 0.1335 - accuracy: 0.9805 - val_loss: 0.3979 - val_accuracy: 0.9191
# Epoch 8/30
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0914 - accuracy: 0.9941 - val_loss: 0.4277 - val_accuracy: 0.9044
# Epoch 9/30
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0581 - accuracy: 0.9993 - val_loss: 0.3873 - val_accuracy: 0.9222
# Epoch 10/30
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0341 - accuracy: 0.9991 - val_loss: 0.4258 - val_accuracy: 0.9126
# Epoch 11/30
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0281 - accuracy: 0.9984 - val_loss: 0.4025 - val_accuracy: 0.9168
# ============== End Client2 ===============
# ===============  Client3  ================
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 32) 160         deep_input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 32)   4128        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   8256        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 16384)        0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1024)         16778240    flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1024)         0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 512)          524800      dropout_6[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 1878)]       0
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2390)         0           wide_input[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# wide_deep (Dense)               (None, 228)          545148      concatenate_3[0][0]
# ==================================================================================================
# Total params: 17,860,732
# Trainable params: 17,860,732
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 41/41 [==============================] - 2s 39ms/step - loss: 38.1906 - accuracy: 0.2495 - val_loss: 1.2327 - val_accuracy: 0.7238
# Epoch 2/30
# 41/41 [==============================] - 1s 25ms/step - loss: 1.0692 - accuracy: 0.7672 - val_loss: 0.7900 - val_accuracy: 0.8375
# Epoch 3/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6590 - accuracy: 0.8611 - val_loss: 0.5814 - val_accuracy: 0.8867
# Epoch 4/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4209 - accuracy: 0.9106 - val_loss: 0.4898 - val_accuracy: 0.9041
# Epoch 5/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3085 - accuracy: 0.9433 - val_loss: 0.8387 - val_accuracy: 0.8000
# Epoch 6/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3140 - accuracy: 0.9396 - val_loss: 0.4121 - val_accuracy: 0.9184
# Epoch 7/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1829 - accuracy: 0.9663 - val_loss: 0.4243 - val_accuracy: 0.9215
# Epoch 8/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1540 - accuracy: 0.9727 - val_loss: 0.3640 - val_accuracy: 0.9315
# Epoch 9/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1069 - accuracy: 0.9870 - val_loss: 0.3489 - val_accuracy: 0.9362
# Epoch 10/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0762 - accuracy: 0.9940 - val_loss: 0.3730 - val_accuracy: 0.9280
# Epoch 11/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0708 - accuracy: 0.9901 - val_loss: 0.3354 - val_accuracy: 0.9404
# Epoch 12/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0583 - accuracy: 0.9977 - val_loss: 0.3632 - val_accuracy: 0.9273
# Epoch 13/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0486 - accuracy: 0.9950 - val_loss: 0.3591 - val_accuracy: 0.9342
# ============== End Client3 ===============

# %%
y_pred = server.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Server: ', accuracy_score(y_test, y_pred))
y_pred = client1.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client1: ', accuracy_score(y_test, y_pred))
y_pred = client2.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client2: ', accuracy_score(y_test, y_pred))
y_pred = client3.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client3: ', accuracy_score(y_test, y_pred))
# Out:
# Server:  0.9206963249516441
# Client1:  0.9214700193423597
# Client2:  0.9137330754352031
# Client3:  0.9315280464216634

# %% [markdown]
# Bước 2: Trung bình cộng bộ trọng số của 4

# %%
weights_avg = (np.array(server.get_weights()) + np.array(client1.get_weights()) + np.array(client2.get_weights()) + np.array(client3.get_weights())) / 4
server.set_weights(weights_avg)
client1.set_weights(weights_avg)
client2.set_weights(weights_avg)
client3.set_weights(weights_avg)

y_pred = server.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Server: ', accuracy_score(y_test, y_pred))
y_pred = client1.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client1: ', accuracy_score(y_test, y_pred))
y_pred = client2.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client2: ', accuracy_score(y_test, y_pred))
y_pred = client3.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client3: ', accuracy_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# Server:  0.8731141199226305
# Client1:  0.8731141199226305
# Client2:  0.8731141199226305
# Client3:  0.8731141199226305

# %% [markdown]
# Bước 3: Lấy 2 máy tiếp tục train
#
#
# *   Client1(files[6])
# *   Client2(files[7])

# %%
#client1
print('===============  Client1  ================')
x_train_wide = files[6][:, 16386:].astype('float')
x_train_deep = tranform(files[6][:, 3:16386]).astype('float')
y_train = to_categorical(files[6][:, 2].astype('int'), 228)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_client1.h5', monitor='val_loss', save_best_only=True)]
client1.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Client1 ===============')
del x_train_wide, x_train_deep, y_train
#client2
print('===============  Client2  ================')
x_train_wide = files[7][:, 16386:].astype('float')
x_train_deep = tranform(files[7][:, 3:16386]).astype('float')
y_train = to_categorical(files[7][:, 2].astype('int'), 228)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_client2.h5', monitor='val_loss', save_best_only=True)]
client2.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Client2 ===============')
del x_train_wide, x_train_deep, y_train
# Out:
# ===============  Client1  ================
# Epoch 1/30
# 41/41 [==============================] - 1s 34ms/step - loss: 0.4899 - accuracy: 0.9310 - val_loss: 0.2965 - val_accuracy: 0.9602
# Epoch 2/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2391 - accuracy: 0.9601 - val_loss: 0.2434 - val_accuracy: 0.9590
# Epoch 3/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1861 - accuracy: 0.9670 - val_loss: 0.2259 - val_accuracy: 0.9598
# Epoch 4/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1445 - accuracy: 0.9756 - val_loss: 0.2091 - val_accuracy: 0.9652
# Epoch 5/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1189 - accuracy: 0.9845 - val_loss: 0.2023 - val_accuracy: 0.9663
# Epoch 6/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1040 - accuracy: 0.9880 - val_loss: 0.1930 - val_accuracy: 0.9667
# Epoch 7/30
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0853 - accuracy: 0.9899 - val_loss: 0.1859 - val_accuracy: 0.9679
# Epoch 8/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0770 - accuracy: 0.9903 - val_loss: 0.1761 - val_accuracy: 0.9718
# Epoch 9/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0628 - accuracy: 0.9946 - val_loss: 0.1713 - val_accuracy: 0.9714
# Epoch 10/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0555 - accuracy: 0.9969 - val_loss: 0.1729 - val_accuracy: 0.9675
# Epoch 11/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0520 - accuracy: 0.9946 - val_loss: 0.1629 - val_accuracy: 0.9714
# Epoch 12/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0424 - accuracy: 0.9969 - val_loss: 0.1865 - val_accuracy: 0.9683
# Epoch 13/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0375 - accuracy: 0.9977 - val_loss: 0.1662 - val_accuracy: 0.9687
# ============== End Client1 ===============
# ===============  Client2  ================
# Epoch 1/30
# 41/41 [==============================] - 1s 34ms/step - loss: 0.4543 - accuracy: 0.9286 - val_loss: 0.2977 - val_accuracy: 0.9598
# Epoch 2/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2414 - accuracy: 0.9566 - val_loss: 0.2429 - val_accuracy: 0.9598
# Epoch 3/30
# 41/41 [==============================] - 1s 25ms/step - loss: 0.1786 - accuracy: 0.9705 - val_loss: 0.2415 - val_accuracy: 0.9652
# Epoch 4/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1507 - accuracy: 0.9740 - val_loss: 0.2221 - val_accuracy: 0.9613
# Epoch 5/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1272 - accuracy: 0.9814 - val_loss: 0.1998 - val_accuracy: 0.9687
# Epoch 6/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1020 - accuracy: 0.9829 - val_loss: 0.2042 - val_accuracy: 0.9648
# Epoch 7/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0885 - accuracy: 0.9872 - val_loss: 0.1984 - val_accuracy: 0.9652
# Epoch 8/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0742 - accuracy: 0.9903 - val_loss: 0.2088 - val_accuracy: 0.9625
# Epoch 9/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0669 - accuracy: 0.9895 - val_loss: 0.1867 - val_accuracy: 0.9629
# Epoch 10/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0544 - accuracy: 0.9934 - val_loss: 0.1839 - val_accuracy: 0.9663
# Epoch 11/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0488 - accuracy: 0.9946 - val_loss: 0.1798 - val_accuracy: 0.9656
# Epoch 12/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0415 - accuracy: 0.9961 - val_loss: 0.1836 - val_accuracy: 0.9636
# Epoch 13/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0395 - accuracy: 0.9957 - val_loss: 0.1799 - val_accuracy: 0.9667
# ============== End Client2 ===============

# %%
y_pred = server.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Server: ', accuracy_score(y_test, y_pred))
y_pred = client1.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client1: ', accuracy_score(y_test, y_pred))
y_pred = client2.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client2: ', accuracy_score(y_test, y_pred))
y_pred = client3.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client3: ', accuracy_score(y_test, y_pred))
# Out:
# Server:  0.8731141199226305
# Client1:  0.9694390715667311
# Client2:  0.9647969052224371
# Client3:  0.8731141199226305

# %% [markdown]
# Bước 4: Tính trung bình cộng của client1 và client 2 vừa train, cập nhật lại 4 máy

# %%
weights_avg = (np.array(server.get_weights()) + np.array(client1.get_weights()) + np.array(client2.get_weights())) / 3
server.set_weights(weights_avg)
client1.set_weights(weights_avg)
client2.set_weights(weights_avg)
client3.set_weights(weights_avg)

y_pred = server.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Server: ', accuracy_score(y_test, y_pred))
y_pred = client1.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client1: ', accuracy_score(y_test, y_pred))
y_pred = client2.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client2: ', accuracy_score(y_test, y_pred))
y_pred = client3.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client3: ', accuracy_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# Server:  0.9609284332688588
# Client1:  0.9609284332688588
# Client2:  0.9609284332688588
# Client3:  0.9609284332688588

# %% [markdown]
# Bước 5: Lặp lại bước 3 và 4

# %%
#========================Lặp lại bước 3==============================
#client1
print('===============  Client1  ================')
x_train_wide = files[8][:, 16386:].astype('float')
x_train_deep = tranform(files[8][:, 3:16386]).astype('float')
y_train = to_categorical(files[8][:, 2].astype('int'), 228)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_client1.h5', monitor='val_loss', save_best_only=True)]
client1.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Client1 ===============')
del x_train_wide, x_train_deep, y_train
#client2
print('===============  Client2  ================')
x_train_wide = files[9][:, 16386:].astype('float')
x_train_deep = tranform(files[9][:, 3:16386]).astype('float')
y_train = to_categorical(files[9][:, 2].astype('int'), 228)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model_client2.h5', monitor='val_loss', save_best_only=True)]
client2.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)
print('============== End Client2 ===============')
del x_train_wide, x_train_deep, y_train
y_pred = server.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
sv_b3 = accuracy_score(y_test, y_pred)
y_pred = client1.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
c1_b3 = accuracy_score(y_test, y_pred)
y_pred = client2.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
c2_b3 = accuracy_score(y_test, y_pred)
y_pred = client3.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
c3_b3 = accuracy_score(y_test, y_pred)
#========================Lặp lại bước 4==============================
weights_avg = (np.array(server.get_weights()) + np.array(client1.get_weights()) + np.array(client2.get_weights())) / 3
server.set_weights(weights_avg)
client1.set_weights(weights_avg)
client2.set_weights(weights_avg)
client3.set_weights(weights_avg)

print('==================Kết quả lặp lại bước 3=================')
print('Server: ', sv_b3)
print('Client1: ', c1_b3)
print('Client2: ', c2_b3)
print('Client3: ', c3_b3)
print('==================Kết quả lặp lại bước 4=================')
y_pred = server.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Server: ', accuracy_score(y_test, y_pred))
y_pred = client1.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client1: ', accuracy_score(y_test, y_pred))
y_pred = client2.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client2: ', accuracy_score(y_test, y_pred))
y_pred = client3.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('Client3: ', accuracy_score(y_test, y_pred))
# Out:
# ===============  Client1  ================
# Epoch 1/30
# 41/41 [==============================] - 1s 35ms/step - loss: 0.2081 - accuracy: 0.9604 - val_loss: 0.1823 - val_accuracy: 0.9675
# Epoch 2/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1295 - accuracy: 0.9771 - val_loss: 0.1694 - val_accuracy: 0.9779
# Epoch 3/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1000 - accuracy: 0.9833 - val_loss: 0.1622 - val_accuracy: 0.9737
# Epoch 4/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0881 - accuracy: 0.9856 - val_loss: 0.1515 - val_accuracy: 0.9764
# Epoch 5/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0741 - accuracy: 0.9899 - val_loss: 0.1515 - val_accuracy: 0.9749
# Epoch 6/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0602 - accuracy: 0.9919 - val_loss: 0.1452 - val_accuracy: 0.9756
# Epoch 7/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0502 - accuracy: 0.9938 - val_loss: 0.1455 - val_accuracy: 0.9768
# Epoch 8/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0413 - accuracy: 0.9957 - val_loss: 0.1399 - val_accuracy: 0.9768
# Epoch 9/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0386 - accuracy: 0.9977 - val_loss: 0.1425 - val_accuracy: 0.9752
# Epoch 10/30
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0329 - accuracy: 0.9977 - val_loss: 0.1466 - val_accuracy: 0.9776
# ============== End Client1 ===============
# ===============  Client2  ================
# Epoch 1/30
# 44/44 [==============================] - 1s 34ms/step - loss: 0.2354 - accuracy: 0.9545 - val_loss: 0.2057 - val_accuracy: 0.9691
# Epoch 2/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.1481 - accuracy: 0.9688 - val_loss: 0.1625 - val_accuracy: 0.9718
# Epoch 3/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0997 - accuracy: 0.9839 - val_loss: 0.1446 - val_accuracy: 0.9772
# Epoch 4/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0769 - accuracy: 0.9893 - val_loss: 0.1417 - val_accuracy: 0.9772
# Epoch 5/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0636 - accuracy: 0.9928 - val_loss: 0.1438 - val_accuracy: 0.9729
# Epoch 6/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0535 - accuracy: 0.9943 - val_loss: 0.1328 - val_accuracy: 0.9768
# Epoch 7/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0423 - accuracy: 0.9964 - val_loss: 0.1295 - val_accuracy: 0.9772
# Epoch 8/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0364 - accuracy: 0.9986 - val_loss: 0.1289 - val_accuracy: 0.9760
# Epoch 9/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0298 - accuracy: 0.9989 - val_loss: 0.1261 - val_accuracy: 0.9760
# Epoch 10/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0241 - accuracy: 0.9986 - val_loss: 0.1297 - val_accuracy: 0.9749
# Epoch 11/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0200 - accuracy: 0.9993 - val_loss: 0.1275 - val_accuracy: 0.9745
# ============== End Client2 ===============
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ==================Kết quả lặp lại bước 3=================
# Server:  0.9609284332688588
# Client1:  0.9748549323017408
# Client2:  0.9756286266924564
# Client3:  0.9609284332688588
# ==================Kết quả lặp lại bước 4=================
# Server:  0.9744680851063829
# Client1:  0.9744680851063829
# Client2:  0.9744680851063829
# Client3:  0.9744680851063829

# %% [markdown]
# Bước 6: Chạy WnDCNN bình thường với train[file2, file9], val[file0], test[file1]

# %%
# del server, client1, client2, client3, callbacks, files[0], files[1], y_pred#, y_train, y_val, x_train_deep, x_train_wide, x_val_deep, x_val_wide

train = np.concatenate([files[i] for i in range(8)], axis=0)
x_train_wide = train[:, 16386:].astype('float')
x_train_deep = tranform(train[:, 3:16386]).astype('float')
y_train = to_categorical(train[:, 2].astype('int'), 228)
model = WnDCNN(wide_input_shape, deep_input_shape)
callbacks = [EarlyStopping(monitor='val_loss', patience=2), ModelCheckpoint(filepath='/content/drive/My Drive/best_model.h5', monitor='val_loss', save_best_only=True)]
model.fit([x_train_wide, x_train_deep], y_train, epochs=30, batch_size=64, validation_data=([x_val_wide, x_val_deep], y_val), callbacks=callbacks)

y_pred = model.predict([x_test_wide, x_test_deep])
y_pred = np.argmax(y_pred, axis=-1)
print('model: ', accuracy_score(y_test, y_pred))
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 32) 160         deep_input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 64, 64, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   4128        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 64)   8256        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 16384)        0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1024)         16778240    flatten_5[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 1024)         0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 512)          524800      dropout_10[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 1878)]       0
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           dense_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 2390)         0           wide_input[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# wide_deep (Dense)               (None, 228)          545148      concatenate_5[0][0]
# ==================================================================================================
# Total params: 17,860,732
# Trainable params: 17,860,732
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 326/326 [==============================] - 7s 20ms/step - loss: 8.9882 - accuracy: 0.6478 - val_loss: 0.2414 - val_accuracy: 0.9609
# Epoch 2/30
# 326/326 [==============================] - 6s 17ms/step - loss: 0.1959 - accuracy: 0.9597 - val_loss: 0.1331 - val_accuracy: 0.9772
# Epoch 3/30
# 326/326 [==============================] - 6s 18ms/step - loss: 0.1019 - accuracy: 0.9789 - val_loss: 0.1042 - val_accuracy: 0.9779
# Epoch 4/30
# 326/326 [==============================] - 6s 17ms/step - loss: 0.0637 - accuracy: 0.9884 - val_loss: 0.0885 - val_accuracy: 0.9845
# Epoch 5/30
# 326/326 [==============================] - 6s 17ms/step - loss: 0.0457 - accuracy: 0.9911 - val_loss: 0.0777 - val_accuracy: 0.9872
# Epoch 6/30
# 326/326 [==============================] - 6s 17ms/step - loss: 0.0319 - accuracy: 0.9961 - val_loss: 0.0688 - val_accuracy: 0.9872
# Epoch 7/30
# 326/326 [==============================] - 6s 17ms/step - loss: 0.0274 - accuracy: 0.9953 - val_loss: 0.0669 - val_accuracy: 0.9868
# Epoch 8/30
# 326/326 [==============================] - 6s 17ms/step - loss: 0.0199 - accuracy: 0.9976 - val_loss: 0.0684 - val_accuracy: 0.9880
# Epoch 9/30
# 326/326 [==============================] - 6s 17ms/step - loss: 0.0135 - accuracy: 0.9986 - val_loss: 0.0718 - val_accuracy: 0.9834
# model:  0.9984526112185687
